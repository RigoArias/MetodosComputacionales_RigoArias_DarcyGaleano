# %% [markdown]
# <a href="https://colab.research.google.com/github/RigoArias/MetodosComputacionales_RigoArias_DarcyGaleano/blob/main/Taller_3_Integracion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

R = 1
n = 100
x = np.linspace(-R, R, n + 1)
y = np.linspace(-R, R, n + 1)
X, Y = np.meshgrid(x, y)

def z_axis(x,y):
  z = np.sqrt(R**2 - x**2 - y**2)
  return np.where(x**2 + y**2 <= R**2, z, 0.)


z = np.zeros_like(X)

for i in range(X.shape[0]):
  for j in range(X.shape[1]):
    z[i,j] = z_axis(X[i,j],Y[i,j])


fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot_surface(X,Y,z)
# Out:
# <ipython-input-22-2f86d63e2826>:11: RuntimeWarning: invalid value encountered in sqrt
#   z = np.sqrt(R**2 - x**2 - y**2)
